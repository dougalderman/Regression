# %%
x<-c(1,2,3,4,5,6,7)
y<-c(1.9,7.4,11.7.19.5,28.2,29.7,31.3)
relation<-lm(y~x)
# Out:
# Error in parse(text = x, srcfile = src): <text>:2:18: unexpected numeric constant
# 1: x<-c(1,2,3,4,5,6,7)
# 2: y<-c(1.9,7.4,11.7.19
#                     ^
# Traceback:

# %%
x<-c(1,2,3,4,5,6,7)
y<-c(1.9,7.4,11.7,19.5,28.2,29.7,31.3)
relation<-lm(y~x)
print(relation)
# Out:
# Call:
# lm(formula = y ~ x)
#
# Coefficients:
# (Intercept)            x
#      -2.800        5.332

# %%
png(file="lr.png")
plot(y,x,col="blue", main="Linear Regression Example",abline(lm(x~y)))

# %%
png(file="lr.png")
plot(y,x,col="blue", main="Linear Regression Example",abline(lm(x~y)))

# %%
png(file="lr2.png")
plot(y,x,col="blue", main="Linear Regression Example",abline(lm(x~y)), cex=1.3,pch=16,xlab="x", ylab="y")
dev.off()
# Out:
# png
#   2

# %%
png(file="lr2.png")
plot(y,x,col="blue", main="Linear Regression Example",abline(lm(y~x)), cex=1.3,pch=16,xlab="x", ylab="y")
dev.off()
# Out:
# png
#   2

# %%
plot(y,x,col="blue", main="Linear Regression Example",abline(lm(y~x)), cex=1.3,pch=16,xlab="x", ylab="y")
dev.off()
# Out:
# png
#   3
# Plot with title “Linear Regression Example”

# %%
plot(x,y,col="blue", main="Linear Regression Example",abline(lm(y~x)), cex=1.3,pch=16,xlab="x", ylab="y")
dev.off()
# Out:
# png
#   3
# Plot with title “Linear Regression Example”

# %%
png(file="lr3.png")
plot(x,y,col="blue", main="Linear Regression Example",abline(lm(y~x)), cex=1.3,pch=16,xlab="x", ylab="y")
dev.off()
# Out:
# png
#   2

# %%
x<-c(1,2,3,4,5,6,7)
y<-c(1.9,7.4,11.7,19.5,28.2,29.7,31.3)
relation<-lm(y~x)
print(relation)
summary(relation)
# Out:
# Call:
# lm(formula = y ~ x)
#
# Coefficients:
# (Intercept)            x
#      -2.800        5.332
# Call:
# lm(formula = y ~ x)
#
# Residuals:
#       1       2       3       4       5       6       7
# -0.6321 -0.4643 -1.4964  0.9714  4.3393  0.5071 -3.2250
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  -2.8000     2.1806  -1.284 0.255405
# x             5.3321     0.4876  10.936 0.000111 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 2.58 on 5 degrees of freedom
# Multiple R-squared:  0.9599,	Adjusted R-squared:  0.9518
# F-statistic: 119.6 on 1 and 5 DF,  p-value: 0.0001112

# %%
x<-c(1,2,3,4,5,6,7)
y<-c(1.9,7.4,11.7,19.5,28.2,29.7,31.3)
relation<-lm(y~x)
print(relation)
summary(relation)
# Out:
# Call:
# lm(formula = y ~ x)
#
# Coefficients:
# (Intercept)            x
#      -2.800        5.332
# Call:
# lm(formula = y ~ x)
#
# Residuals:
#       1       2       3       4       5       6       7
# -0.6321 -0.4643 -1.4964  0.9714  4.3393  0.5071 -3.2250
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  -2.8000     2.1806  -1.284 0.255405
# x             5.3321     0.4876  10.936 0.000111 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 2.58 on 5 degrees of freedom
# Multiple R-squared:  0.9599,	Adjusted R-squared:  0.9518
# F-statistic: 119.6 on 1 and 5 DF,  p-value: 0.0001112

# %%
confint(relation, level=0.95)
# Out:
#             2.5 %     97.5 %
# (Intercept) -8.405431 2.805431
# x            4.078730 6.585555

# %%
plot(fitted(relation), residuals(relation))
# Out:
# plot without title
